# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelwheeler/Planar_data_tensorflow.ipynb/blob/main/Planar_data_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# start your code here
os.chdir('/content/drive/MyDrive/DEEP LEARNING/Homework2') #make the directory where this ipynb file is as the current working directory. You will need to change this path to the one that you are working with.
# end your code here
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1 - Packages ##
#
# Let's first import all the packages that you will need during this assignment.
# - [numpy](https://www.numpy.org/) is the fundamental package for scientific computing with Python.
# - [sklearn](http://scikit-learn.org/stable/) provides simple and efficient tools for data mining and data analysis.
# - [matplotlib](http://matplotlib.org) is a library for plotting graphs in Python.
# - [tensorflow](https://www.tensorflow.org/) is a library for deep learning.
# - testCases provides some test examples to assess the correctness of your functions
# - planar_utils provide various useful functions used in this assignment

# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
from testCases_v2 import *
from planar_utils import load_planar_dataset
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# ## 2 - Dataset ##
#
# First, let's get the dataset you will work on. The following code will load a "flower" 2-class dataset into variables `X` and `Y`.

# %%
X, Y = load_planar_dataset()
X=X.T
Y=Y.T

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data. In other words, we want the classifier to define regions as either red or blue.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=Y, s=40, cmap=plt.cm.Spectral);

# %% [markdown]
# You have:
#     - a numpy-array (matrix) X that contains your features (x1, x2)
#     - a numpy-array (vector) Y that contains your labels (red:0, blue:1).
#
# Lets first get a better sense of what our data is like.
#
# **Exercise**: How many training examples do you have? In addition, what is the `shape` of the variables `X` and `Y`?
#
# **Hint**: How do you get the shape of a numpy array? [(help)](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.shape.html)

# %%
### START CODE HERE ### (≈ 3 lines of code)
shape_X = X.shape
shape_Y = Y.shape
m = X.shape[1]  # training set size
### END CODE HERE ###

print ('The shape of X is: ' + str(shape_X))
print ('The shape of Y is: ' + str(shape_Y))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (400, 2)
# The shape of Y is: (400, 1)
# I have m = 2 training examples!

# %% [markdown]
# ## 3 - Create Your First Neural Network model with TensorFlow
# Assume we are going to build a NN as follows.
#
# ![](https://drive.google.com/uc?export=view&id=1GY7lqAdP8EoWfCcz9c0ygfpGBhjfnL6F)
#
# We are going to introduce two popular ways to build it
#
# ### 3.1 - Sequential model ####
# ```
# model_seq = tf.keras.Sequential([
#     tf.keras.Input(shape=2), # Input layer: every sample (point) has two inputs
#     tf.keras.layers.Dense(4, activation='tanh'), # Hidden layer 1: this layer has 4 neurons, and every neuron use 'tanh' as the activation function
#     tf.keras.layers.Dense(1,activation='sigmoid'), # output layer: this layer has 1 neuron, and the activation function is 'sigmoid'
# ])
#
# model_seq.summary()
# ```
# **Hint**:
#
# 1. How do you build a sequential model? [(help)](https://www.tensorflow.org/guide/keras/sequential_model)
#
# 2. What are the layers in a NN model? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/layers)
#
# 3. What is the Input layer in a NN model? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/Input)
#
# 4. What is the Dense layer in a NN model? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)
#
# 5. Your choices of activation functions. [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# ### 3.2 - API model ####
# ```
# model_API_input = tf.keras.Input(shape=(2)) # Input_layer: every input has shape 2
# x = tf.keras.layers.Dense(4, activation='tanh')(model_API_input) # Hidden layer 1: take layer 'model_API_input' as input, have 4 neurons, and use 'tanh' as the activation function
# model_API_output = tf.keras.layers.Dense(1,activation='sigmoid')(x) # output layer: take layer 'x' as input, have 1 neuron, and use 'sigmoid' as the activation function
#
# model_API = tf.keras.Model(model_API_input, model_API_output, name="model_API")
# model_API.summary()
# ```
# **Hint**:
#
# 1. How do you build a API model? [(help)](https://www.tensorflow.org/guide/keras/functional)
#
# **Exercise**: Build your own NN model with either method.
#
# You can build as many layers as you like.
#
# For every layer, please feel free to choose the number of neurons.
#
# Just to make sure that the shape of the input layer matches the size of each sample, and the number of neurons in the output layer matches the size of the output of each sample.
#
# Please feel free to use 'your_model_name.summary()' to print out the model.

# %%
### START CODE HERE ### 
model_rachel_input = tf.keras.Input(shape=(2))
x = tf.keras.layers.Dense(4,activation='tanh')(model_rachel_input)
x2 = tf.keras.layers.Dense(6,activation='tanh')(x)
model_rachel_output = tf.keras.layers.Dense(1,activation='sigmoid')(x2)

model_rachel = tf.keras.Model(model_rachel_input, model_rachel_output, name = "model_rachel")

### End CODE HERE ###
model_rachel.summary()
# Out:
# Model: "model_rachel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 2)]               0
#
#  dense_12 (Dense)            (None, 4)                 12
#
#  dense_13 (Dense)            (None, 6)                 30
#
#  dense_14 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4 - Train Your First Neural Network Model
# ### 4.1 - Compile your model ####
#
# 1. how we define our loss?
#
# 2. which method to use to find the minimum loss? Sometimes, you may need to specify the 'learning_rate', the step size for every jump.
#
# 3. Which metric to evaluate the model?
# ```
# model_seq.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),  # Optimizer. You may want to try different optimizers to see how they help in this project
#     # Loss function to minimize
#     loss=tf.keras.losses.BinaryCrossentropy(), # usually used for binary classification problems
#     # List of metrics to monitor
#     metrics=['accuracy'])
# ```
#
# **Hint**:
#
# 1. The available optimizers? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)
#
# 2. The available loss functions? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/losses)
#
# 3. The available metric functions? [(help)](https://www.tensorflow.org/api_docs/python/tf/keras/metrics)
#
# ### 4.2 - Train your model ####
#
# We will use 'your_model_name.fit' to train the model. In this function, we have several parameters to tune, shown as below.
#
# ```
# history = model_seq.fit(
#     X, # input data
#     Y, # real output data
#     batch_size=64, # how many samples (points) do you want to use to update weights once? If you have 640 samples, you can update the weight 10 times for every iteration/epoch
#     epochs=10, # how many iterations do you want to train your model? Your data will be reused to train the model for 10 times.
# )
# ```
#
# Please feel free to change the 'batch_size' and the 'epochs' to see how the parameters influence the training process.
#
# **Hint**:
#
# 1. How to train your model? [(help)](https://www.tensorflow.org/guide/keras/train_and_evaluate)
#
# **Exercise**: Compile and train your model.
#
# Please feel free to adjust the parameters in both the 'compile' and the 'fit' function to improve the performance.

# %%
### START CODE HERE ### 
model_rachel.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=.0015),loss = tf.keras.losses.BinaryCrossentropy(),metrics = ['accuracy'])

history = model_rachel.fit(X,Y,batch_size=14, epochs=153)
### End CODE HERE ###
# Out:
# Epoch 1/153
# 29/29 [==============================] - 1s 2ms/step - loss: 0.2357 - accuracy: 0.9000
# Epoch 2/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.9025
# Epoch 3/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9000
# Epoch 4/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.9025
# Epoch 5/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.8975
# Epoch 6/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.8975
# Epoch 7/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9025
# Epoch 8/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9000
# Epoch 9/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.9000
# Epoch 10/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9000
# Epoch 11/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.9000
# Epoch 12/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.8975
# Epoch 13/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9000
# Epoch 14/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9000
# Epoch 15/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.9000
# Epoch 16/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 0.8975
# Epoch 17/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.8975
# Epoch 18/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9025
# Epoch 19/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.8975
# Epoch 20/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2345 - accuracy: 0.9025
# Epoch 21/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9000
# Epoch 22/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.8975
# Epoch 23/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.8975
# Epoch 24/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9025
# Epoch 25/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2337 - accuracy: 0.9025
# Epoch 26/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2340 - accuracy: 0.9000
# Epoch 27/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9000
# Epoch 28/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2340 - accuracy: 0.9025
# Epoch 29/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9000
# Epoch 30/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.8975
# Epoch 31/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.8975
# Epoch 32/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9000
# Epoch 33/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2334 - accuracy: 0.8975
# Epoch 34/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.8975
# Epoch 35/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8975
# Epoch 36/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.9025
# Epoch 37/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.8975
# Epoch 38/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.9000
# Epoch 39/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.8975
# Epoch 40/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8975
# Epoch 41/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9000
# Epoch 42/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.8975
# Epoch 43/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9000
# Epoch 44/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.8975
# Epoch 45/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.8975
# Epoch 46/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9000
# Epoch 47/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.9000
# Epoch 48/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.9000
# Epoch 49/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.8975
# Epoch 50/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.8975
# Epoch 51/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2333 - accuracy: 0.9025
# Epoch 52/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8975
# Epoch 53/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.9000
# Epoch 54/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9000
# Epoch 55/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2330 - accuracy: 0.9000
# Epoch 56/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9000
# Epoch 57/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.8975
# Epoch 58/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9000
# Epoch 59/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.9050
# Epoch 60/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.8975
# Epoch 61/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.8975
# Epoch 62/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9000
# Epoch 63/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.8950
# Epoch 64/153
# 29/29 [==============================] - 0s 1ms/step - loss: 0.2329 - accuracy: 0.9000
# Epoch 65/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.8975
# Epoch 66/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2329 - accuracy: 0.9000
# Epoch 67/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.8975
# Epoch 68/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9025
# Epoch 69/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.8975
# Epoch 70/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2329 - accuracy: 0.9000
# Epoch 71/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.9000
# Epoch 72/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9000
# Epoch 73/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9025
# Epoch 74/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.8975
# Epoch 75/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2322 - accuracy: 0.8975
# Epoch 76/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.8975
# Epoch 77/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.8975
# Epoch 78/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2319 - accuracy: 0.9000
# Epoch 79/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.8975
# Epoch 80/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9000
# Epoch 81/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2321 - accuracy: 0.9025
# Epoch 82/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.8975
# Epoch 83/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.8975
# Epoch 84/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9000
# Epoch 85/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.8975
# Epoch 86/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9025
# Epoch 87/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9000
# Epoch 88/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.8975
# Epoch 89/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.8975
# Epoch 90/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.8975
# Epoch 91/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9025
# Epoch 92/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.8975
# Epoch 93/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9000
# Epoch 94/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9000
# Epoch 95/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9000
# Epoch 96/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.8950
# Epoch 97/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2315 - accuracy: 0.9000
# Epoch 98/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.8975
# Epoch 99/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9000
# Epoch 100/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.8975
# Epoch 101/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9000
# Epoch 102/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2315 - accuracy: 0.8975
# Epoch 103/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.8975
# Epoch 104/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.8975
# Epoch 105/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.8975
# Epoch 106/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.9050
# Epoch 107/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.8975
# Epoch 108/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.8975
# Epoch 109/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9000
# Epoch 110/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9025
# Epoch 111/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.8975
# Epoch 112/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9025
# Epoch 113/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.8975
# Epoch 114/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.8975
# Epoch 115/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.8975
# Epoch 116/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.9000
# Epoch 117/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9025
# Epoch 118/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.8975
# Epoch 119/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9025
# Epoch 120/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2307 - accuracy: 0.8975
# Epoch 121/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.8975
# Epoch 122/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.9000
# Epoch 123/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9000
# Epoch 124/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9000
# Epoch 125/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2307 - accuracy: 0.8975
# Epoch 126/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.8975
# Epoch 127/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.8975
# Epoch 128/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2298 - accuracy: 0.9025
# Epoch 129/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.8975
# Epoch 130/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9025
# Epoch 131/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9000
# Epoch 132/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9025
# Epoch 133/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.8975
# Epoch 134/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9025
# Epoch 135/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.8975
# Epoch 136/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.8950
# Epoch 137/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9025
# Epoch 138/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.8950
# Epoch 139/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.8975
# Epoch 140/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9025
# Epoch 141/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9000
# Epoch 142/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.8975
# Epoch 143/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.8975
# Epoch 144/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9050
# Epoch 145/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2296 - accuracy: 0.9000
# Epoch 146/153
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2299 - accuracy: 0.9025
# Epoch 147/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.8975
# Epoch 148/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.9000
# Epoch 149/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2296 - accuracy: 0.9025
# Epoch 150/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9025
# Epoch 151/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2288 - accuracy: 0.9000
# Epoch 152/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2302 - accuracy: 0.9000
# Epoch 153/153
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9025

# %% [markdown]
# **Expected output**: You are free to design your own neural network, choose your own optimizer, adjust your 'epochs', 'learning rate', and 'batch_size'. At the end of the epochs, the 'accuracy' should be greater than 0.9

# %% [markdown]
# ## 4 - Visualize your prediction
# We define a function 'plot_boundary_tf(your_model_name, X, y)' to plot the boundary of the trained model. Please change the 'your_model_name' to the name of your model to visualize the result.

# %%
# Plot the decision boundary
def plot_boundary_tf(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
    y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
    h = 0.1
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    test_input=np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(test_input)
    Z = Z.reshape(xx.shape)
    Z01 = (Z>0.5)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z01, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)
    
### START CODE HERE ###   
plot_boundary_tf(model_rachel, X.T, Y.T) # change the first parameter to be your model name to visualize your model prediction
### END CODE HERE ###
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')
